# %%
from src.archs_models import stdlogistic
from src.archs_models import linear
import numpy as np
import matplotlib.pyplot as plt


X = np.random.rand(8000,24)
W = W = np.random.uniform(0, 0.02, (24, 1))
Y = linear(X,W)
print (Y)

# Plotting
plt.plot(X,Y)
# naming the x axis
plt.xlabel('X-Axis')
# naming the y axis
plt.ylabel('Y-Axis')
 
# giving a title to my graph
plt.title('Linear Graph')

# Add grid lines
plt.grid()

# show a legend on the plot
plt.legend()

# plotting the points
plt.plot(X, Y, color='green', linestyle='dashed', linewidth = 3, marker='*', markerfacecolor='blue', markersize=12)
 
# function to show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.52082289]
#  [0.52781164]
#  [0.53469391]
#  ...
#  [0.52877218]
#  [0.52844756]
#  [0.53683031]]
